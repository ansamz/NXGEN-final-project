# %% [markdown]
# # Quality indicator data: hospitals by location and department with disease description

# %% [markdown]
# ## Install deepl module
#
# `deepl` module will be used to translate the features to english: https://www.deepl.com/pro-api?cta=header-pro-api/

# %%
# !pip install selenium
# !pip install --upgrade deepl
import deepl
! pip install streamlit
import streamlit as st

# %% [markdown]
# ## Import necessary modules:

# %%
import pandas as pd
import numpy as np
import re
import json
import time
from pymongo import collection
from enum import Enum
import plotly.express as px

# %% [markdown]
# ## Import data in desired format:

# %%
df = pd.read_csv("src/raw/quality_indicators.csv",
                    encoding = "ISO-8859-1",
                    sep="\n",
                    nrows=50)
df = df.iloc[ : , 0].str.split(';', expand=True)

# %%
df
# Out:
#                                             0  \
# 0   Les Hôpitaux Universitaires de Genève HUG
# 1   Les Hôpitaux Universitaires de Genève HUG
# 2   Les Hôpitaux Universitaires de Genève HUG
# 3   Les Hôpitaux Universitaires de Genève HUG
# 4   Les Hôpitaux Universitaires de Genève HUG
# 5   Les Hôpitaux Universitaires de Genève HUG
# 6   Les Hôpitaux Universitaires de Genève HUG
# 7   Les Hôpitaux Universitaires de Genève HUG
# 8   Les Hôpitaux Universitaires de Genève HUG
# 9   Les Hôpitaux Universitaires de Genève HUG
# 10  Les Hôpitaux Universitaires de Genève HUG
# 11  Les Hôpitaux Universitaires de Genève HUG
# 12  Les Hôpitaux Universitaires de Genève HUG
# 13  Les Hôpitaux Universitaires de Genève HUG
# 14  Les Hôpitaux Universitaires de Genève HUG
# 15  Les Hôpitaux Universitaires de Genève HUG
# 16  Les Hôpitaux Universitaires de Genève HUG
# 17  Les Hôpitaux Universitaires de Genève HUG
# 18  Les Hôpitaux Universitaires de Genève HUG
# 19  Les Hôpitaux Universitaires de Genève HUG
# 20  Les Hôpitaux Universitaires de Genève HUG
# 21  Les Hôpitaux Universitaires de Genève HUG
# 22  Les Hôpitaux Universitaires de Genève HUG
# 23  Les Hôpitaux Universitaires de Genève HUG
# 24  Les Hôpitaux Universitaires de Genève HUG
# 25  Les Hôpitaux Universitaires de Genève HUG
# 26  Les Hôpitaux Universitaires de Genève HUG
# 27  Les Hôpitaux Universitaires de Genève HUG
# 28  Les Hôpitaux Universitaires de Genève HUG
# 29  Les Hôpitaux Universitaires de Genève HUG
# 30  Les Hôpitaux Universitaires de Genève HUG
# 31  Les Hôpitaux Universitaires de Genève HUG
# 32  Les Hôpitaux Universitaires de Genève HUG
# 33  Les Hôpitaux Universitaires de Genève HUG
# 34  Les Hôpitaux Universitaires de Genève HUG
# 35  Les Hôpitaux Universitaires de Genève HUG
# 36  Les Hôpitaux Universitaires de Genève HUG
# 37  Les Hôpitaux Universitaires de Genève HUG
# 38  Les Hôpitaux Universitaires de Genève HUG
# 39  Les Hôpitaux Universitaires de Genève HUG
# 40  Les Hôpitaux Universitaires de Genève HUG
# 41  Les Hôpitaux Universitaires de Genève HUG
# 42  Les Hôpitaux Universitaires de Genève HUG
# 43  Les Hôpitaux Universitaires de Genève HUG
# 44  Les Hôpitaux Universitaires de Genève HUG
# 45  Les Hôpitaux Universitaires de Genève HUG
# 46  Les Hôpitaux Universitaires de Genève HUG
# 47  Les Hôpitaux Universitaires de Genève HUG
# 48  Les Hôpitaux Universitaires de Genève HUG
# 49  Les Hôpitaux Universitaires de Genève HUG
#
#                                                     1      2      3    4  \
# 0                               A Maladies cardiaques
# 1                           A.1 Infarctus du myocarde
# 2   A.1.1.M DP infarctus du myocarde (âge >19), mo...   5.3%   5.3%    1
# 3   A.1.2.M DP infarctus du myocarde, âge 20-44, m...   1.6%   1.2%  1.4
# 4   A.1.3.M DP infarctus du myocarde, âge 45-64, m...   2.4%   1.7%  1.4
# 5   A.1.4.M DP infarctus du myocarde, âge 65-84, m...   5.7%   5.2%  1.1
# 6   A.1.5.M DP infarctus du myocarde, âge >84, mor...  12.8%  16.3%  0.8
# 7   A.1.7.M DP infarctus du myocarde (âge >19), ad...   5.5%   6.8%  0.8
# 8   A.1.8.M DP infarctus du myocarde (âge >19), tr...   5.3%   4.5%  1.2
# 9   A.1.14.P DP infarctus du myocarde avec cathété...  84.5%  62.2%    *
# 10  A.1.15.P DP infarctus du myocarde avec cathété...  87.0%  58.8%    *
# 11  A.1.16.P DP infarctus du myocarde avec cathété...  57.6%  72.3%    *
# 12  A.1.17.P DP infarctus du myocarde avec cathété...  87.3%  59.3%    *
# 13  A.1.9.P Infarctus aigu du myocarde non précisé...   1.0%   1.7%    *
# 14  A.1.10.M Infarctus du myocarde transmural (âge...   6.1%   6.8%  0.9
# 15  A.1.10.P Infarctus du myocarde transmural (âge...  42.0%  41.3%    *
# 16  A.1.11.M Infarctus non transmural/NSTEMI (âge ...   4.5%   3.7%  1.2
# 17  A.1.13.M DS infarctus du myocarde (âge >19), m...  19.5%  15.8%  1.2
# 18                         A.2 Insuffisance cardiaque
# 19  A.2.1.M DP insuffisance cardiaque (âge >19), m...   7.3%   8.6%  0.9
# 20  A.2.2.M DP insuffisance cardiaque, âge 20-44, ...   3.4%   3.1%  1.1
# 21  A.2.3.M DP insuffisance cardiaque, âge 45-64, ...   2.1%   3.4%  0.6
# 22  A.2.4.M DP insuffisance cardiaque, âge 65-84, ...   5.2%   6.8%  0.8
# 23  A.2.5.M DP insuffisance cardiaque, âge >84, mo...  10.4%  11.5%  0.9
# 24  A.2.6.P NYHA IV en cas de DP insuffisance vent...  59.2%  55.7%    *
# 25                         A.3 Cathétérisme cardiaque
# 26  A.3.1.F Cas avec cathétérisme des vaisseaux co...      *      *    *
# 27  A.3.2.M Cathétérisme des vaisseaux coronaires ...   3.1%   3.3%  0.9
# 28  A.3.9.M Cathétérisme des vaisseaux coronaires ...   1.5%   2.5%  0.6
# 29  A.3.10.M Cathétérisme des vaisseaux coronaires...      *      *    *
# 30  A.3.4.M Cathétérisme diagnostique des vaisseau...   3.9%   1.6%  2.5
# 31  A.3.11.M Cathétérisme diagnostique des vaissea...   1.1%   3.0%  0.4
# 32  A.3.12.M Cathétérisme diagnostique des vaissea...      *      *    *
# 33  A.3.7.M Cathétérisme diagnostique des vaisseau...   3.2%   1.3%  2.4
# 34  A.3.5.M Cathétérisme thérapeutique des vaissea...   3.3%   1.3%  2.5
# 35  A.3.5.P Cathétérisme thérapeutique des vaissea...  27.1%  40.9%    *
# 36  A.3.13.M Cathétérisme thérapeutique des vaisse...   0.0%   3.0%    0
# 37  A.3.14.M Cathétérisme thérapeutique des vaisse...      *      *    *
# 38  A.3.8.M Cathétérisme thérapeutique des vaissea...   1.8%   0.9%  2.1
# 39  A.3.6.F Cas avec cathétérisme cardiaque chez l...      *      *    *
# 40                   A.4 Troubles du rythme cardiaque
# 41            A.4.1.F DP troubles du rythme cardiaque      *      *    *
# 42  A.5 Traitement par pacemaker ou défibrillateur...
# 43  A.5.1.F Traitement par pacemaker (implantation...      *      *    *
# 44  A.5.2.F Implantation et changement de défibril...      *      *    *
# 45                        A.6 Traitement par ablation
# 46                      A.6.1.F Ablation par cathéter      *      *    *
# 47  A.6.3.M Ablation de l'oreillette en cas de fib...   0.0%   0.1%    0
# 48  A.6.4.P Complications péricardiques lors de l...      *      *    *
# 49                      A.6.2.F Ablation chirurgicale      *      *    *
#
#         5      6      7    8      9
# 0
# 1
# 2   2'849   4.8%   4.6%    1    621
# 3     188   0.0%   0.1%    0     37
# 4   1'059   3.5%   1.6%  2.2    227
# 5   1'158   4.8%   5.0%    1    271
# 6     444  10.5%  13.4%  0.8     86
# 7   2'491   5.2%   6.2%  0.8    559
# 8     243   3.6%   3.6%    1     28
# 9   2'408  84.7%  64.6%    *    526
# 10  2'268  84.8%  61.0%    *    503
# 11    140  82.1%  76.6%    *     23
# 12  2'276  85.2%  61.4%    *    505
# 13     29      *      *    *      7
# 14  1'196   5.6%   6.2%  0.9    270
# 15  1'196  43.5%  41.3%    *    270
# 16  1'616   4.1%   3.0%  1.4    343
# 17    988  16.5%  13.8%  1.2    243
# 18
# 19  6'445   7.0%   7.7%  0.9  1'462
# 20     58  10.0%   5.7%  1.8     10
# 21    513   2.0%   2.6%  0.8    101
# 22  2'964   4.7%   6.0%  0.8    653
# 23  2'910   9.7%  10.2%    1    698
# 24  1'428  60.0%  54.9%    *    302
# 25
# 26  5'720      *      *    *  1'298
# 27  2'301   3.7%   3.2%  1.1    491
# 28    132   0.0%   2.8%    0     23
# 29      0  25.0%  19.9%  1.3     12
# 30  1'943   2.4%   1.8%  1.4    454
# 31     93   0.0%   1.9%    0     10
# 32      0  53.8%  37.6%  1.4     13
# 33  1'730   2.5%   1.6%  1.6    433
# 34    756   5.3%   1.2%  4.4    151
# 35    756  24.2%  46.7%    *    151
# 36     18      *      *    *      1
# 37      0      *      *    *      1
# 38    661   4.4%   0.9%  4.8    135
# 39    194      *      *    *     21
# 40
# 41  3'276      *      *    *    666
# 42
# 43  1'101      *      *    *    228
# 44    214      *      *    *     53
# 45
# 46  1'167      *      *    *    234
# 47    490   0.0%   0.0%    0    112
# 48      2      *      *    *      1
# 49     65      *      *    *     29

# %% [markdown]
# ## Data pre-processing functions:

# %%
def read_table(csv_path: str, nrows=None, col_names=None) -> pd.DataFrame:
    '''
    Read csv file into dataframe with the correct encoding and separator
    Args:
        csv_path: raw csv file with semicolon and new line separators

    Returns:
        pd.DataFrame: dataframe containing names of hospitals, disease groups with description,
         disease code, mortality, transfer rate, length of hospital stay
    '''
    df = pd.read_csv(csv_path,
                    encoding = "ISO-8859-1",
                    sep="\n",
                    nrows=nrows)
    df = df.iloc[ : , 0].str.split(';', expand=True)

    if col_names:
      raw_cols = df.columns
      raw_cols[ : len(col_names)] = col_names
      df.columns = raw_cols

    return(df)


def load_vocabulary(path_to_vocabulary: str) -> json:
    '''
    Load already created json file to map terms in various languages to English
    Args:
      path_to_vocabulary: path to json file

    Returns:
      json: vocabulary of English terms in json format
    '''
    with open(path_to_vocabulary, "r") as read_file:
      vocabulary = json.load(read_file)
    return(vocabulary)


def create_vocabulary_deepL(terms: pd.Series, filename=None, log=False) -> dict:
    '''
    Translate terms to english and save to json file if
    filename not None
    Args:
      terms: iterable of strings to translate
      filename: save dictionary of translated terms to filepath
      log: write log

    Returns:
      dict: dictionary of phrase in the original language and the translation
    '''
    # auth_key - input your deepl translator key 
    translator = deepl.Translator(auth_key)
    translations = {}
    unique_elements = terms.unique()
    if log:
        print(f'length of unique:{len(unique_elements)}')
        start = time.time()
    for index, element in enumerate(unique_elements):
        translations[element] = translator.translate_text(element, target_lang="EN-GB").text
        if log:
            if index % 100 == 0:
                end = time.time()
                print(f'done {index} elements and time {end - start}')
    if filename != None:
        a_file = open(filename, "w")
        json.dump(translations, a_file)
        a_file.close()
    return (translations)


def translate_terms(terms: pd.Series, load_vocabulary=False, vocabulary_filepath=None) -> dict:
    '''
    Translate an input list of string to english.
    Args: 
        terms: iterable of terms to translate
        load_vocabulary: if true, load json file of already translated terms
        vocabulary_filepath: path to json file to load/save the file from/to
    
    Returns:
        dict: dictionary of terms translated to english
    '''
    if load_vocabulary:
      translations = load_vocabulary(vocabulary_filepath)
    else:
      translations = create_vocabulary_deepL(
          terms,
          filename=vocabulary_filepath
      )
    terms_eng = [translations[element] for element in terms]
    return(terms_eng)


def extract_indicator_code(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Extract disease code and place it in new column
    Args:
        df: dataframe containing names of hospitals, disease groups with description,
         disease code, mortality, transfer rate, length of hospital stay

    Returns:
        pd.DataFrame: dataframe containing separate indicator code column
    '''
    df["code"] = df["indicator_eng"].str.extract('([^\s]+)', expand=True)
    print(f"dim is:{df.shape}")
    return df


def extract_legend(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Retrieve code legend from main dataframe
    Args:
        df: dataframe containing names of hospitals, disease groups with description,
         disease code, mortality, transfer rate, length of hospital stay

    Returns:
        pd.DataFrame: new dataframe containing only code legend
    '''
    code_legend = df[
                    df['code'].str.len() <= 3][
                     ['code', 'indicator_eng']
                    ].drop_duplicates()
    return code_legend


def extract_mortality(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Extract mortality information
    Args:
        df: dataframe containing names of hospitals, disease groups with description,
         disease code, mortality, transfer rate, length of hospital stay

    Returns:
        pd.DataFrame: dataframe with a separate mortality column
    '''
    mortality_codes = df[df['code'].str.endswith(".M")].code.unique()
    df['mortality'] = df['code'].isin(mortality_codes)
    return df


def extract_age(input_string: str) -> str: 
    '''
    Extract age information into a separate string
    Args:
        input_string: string containing disease code, disease description, 
        and age groups with various separators

    Returns:
        str: string containing separate age groups in unified format
    '''
    match = re.search('(?<=\Wage)(.*)', input_string)
    new_string = "None"
    if match:
        placeholder = f"age {match.group(1)[:10]}"
        match = re.search('(?<=age)(\D*)(\d*)(-)(\d*)', placeholder)
        if match:
            new_string = f'{match.group(2)}-{match.group(4)}'
        else:
            match = re.search('(?<=age)(\D*)(\d*)', placeholder)
            if match:
                if ">" in match.group(1):
                    new_string = f'{match.group(2)}-100'
                elif "<" in match.group(1):
                    new_string = f'0-{match.group(2)}'
    return (new_string)


def remove_length_stay(df: pd.DataFrame, length_stay_codes=None) -> pd.DataFrame:
    '''
    Extract length of stay information
    Args:
        df: dataframe containing names of hospitals, disease groups with description,
         disease code, mortality, transfer rate, length of hospital stay

    Returns:
        pd.DataFrame: dataframe without length of stay information
    '''
    if length_stay_codes == None:
      length_stay_codes = [
        'A.1.12.X', 'B.1.15.X', 'E.1.1.X',
        'E.2.1.X', 'F.1.5.X', 'G.3.1.X',
        'H.4.5.X', 'I.1.23.X', 'I.1.24.X',
        'Z.1.1.X'
        ]
    df = df[~df['code'].isin(length_stay_codes)]
    return df


def remove_transfer(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Extract transfer information
    Args:
        df: dataframe containing names of hospitals, disease groups with description,
         disease code, mortality, transfer rate

    Returns:
        pd.DataFrame: dataframe without transfer information
    '''
    df = df[~df['code'].str.endswith(".V")]
    return df


def remove_unuseful_info(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Clean the inputted dataframe from unuseful data - drop columns with all NaN, remove rows without data,
    remove code legend from the dataframe.
    Args:
        df: dataframe containing names of hospitals, disease groups with description,
         disease code, mortality, transfer rate, length of hospital stay

    Returns:
        pd.DataFrame: clean dataframe containing only useful values
    '''
    df.dropna(how='all', axis=1, inplace=True)
    df = df.replace([np.nan, '*', '-', ' ', ''], "None")
    instituzione_row_index = df[df.hospital.str.contains('[I-i]nstitu')].index
    indicator_row_index = df[df.indicator.isin(['indicator', 'indicatore'])].index
    index_to_drop = instituzione_row_index.append(indicator_row_index).unique()
    df = df.drop(index_to_drop)
    code_legend = df[df['code'].str.len() <= 3][['code', 'indicator_eng']].drop_duplicates()
    df = df[~df['code'].isin(code_legend.code)]
    df.replace(regex = ["\\'"], value='', inplace=True)
    def remove_perc(x):
      return(x.astype(str).str.replace('%', ''))
    return df.apply(remove_perc)


def separate_address(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Create separate columns for house number, street, ZIP code and city
    Args:
        df: dataframe containing names of hospitals, disease groups with description,
         disease code, mortality, transfer rate, length of hospital stay

    Returns:
        pd.DataFrame: dataframe with separate columns for address items
    '''
    try:
      sep_interim_df = df["hospital"].str.split(",", expand=True)
      hospital = sep_interim_df[0]
      street_number = sep_interim_df[1]
      ZIP_city = sep_interim_df[2].str.extract('(?P<ZIP>\d+)(?P<City>.*)', expand=True)
      final_df = pd.concat([ZIP_city, df], axis=1)
      final_df['hospital'] = hospital
      final_df.insert(2, 'street_number', street_number)
      final_df.reset_index(inplace=True)
      final_df.drop(["index"], axis=1, inplace=True)
      return(final_df)
    except:
      for col in ['street_number', "ZIP","City"]:
        df[col] = "None"
      return df


def data_wrangling(df: pd.DataFrame) -> pd.DataFrame:
    '''
    Use data preprocessing functions to obtain clean dataframe
    Args:
        df: raw dataframe obtained from initial csv file

    Returns:
        pd.DataFrame: clean data frame with names of hospitals, disease groups with description,
         disease code, mortality, transfer rate, length of hospital stay
    '''
    cols_eng = translate_terms(df.columns)
    indicator_eng = translate_terms(df.indicator)
    df.columns = cols_eng
    df.columns = [
          col_name.replace(" ", "_") for col_name in df.columns
          ]
    df['indicator_eng'] = indicator_eng
    df = extract_indicator_code(df)
    df_legend = extract_legend(df)
    clean_df = df.copy()
    clean_df['age_cat'] = clean_df['indicator_eng'].apply(extract_age)
    clean_df = extract_mortality(clean_df)
    clean_df = remove_length_stay(clean_df)
    clean_df = remove_transfer(clean_df)
    clean_df = separate_address(clean_df)
    clean_df = remove_unuseful_info(clean_df)
    clean_df = clean_df.reset_index().drop(["index"], axis=1)
    return(clean_df)

# %%
# set col names for table_1
col_names_quality_indic = [
  "hospital", 
  "indicator", 
  "observed_rate_2014-2018_%",	
  "expected_rate_2014-2018_%", 
  "therapeutic_value_2014-2018", 
  "number_of_cases_2014-2018", 
  "observed_rate_2019_%",	
  "expected_rate_2019_%", 
  "therapeutic_value_2019", 
  "number_of_cases_2019",
  "None"
  ]



table_qual_indic = read_table(
    csv_path="src/raw/quality_indicators.csv")
# Drop 10th column above 50 rows

# %%
# rename cols
table_qual_indic.columns = col_names_quality_indic
# run pipeline

table_2_w = data_wrangling(table_qual_indic)

# %% [markdown]
# # Exploratory data analysis

# %%
import pandas as pd
import numpy as np
import json
import plotly.express as px

# %% [markdown]
# ## Dataset 2019 based on location:

# %%
def merge_hospital_cantons(df):
  df = df[~df['number_of_cases_2019'].str.contains('None')]
  df['hospital'] = df['hospital'].str.split(' - ').apply(lambda x: x[0].strip())
  df['main_code'] = df['code'].astype(str).str[0]
  disease_group_dict = {'A': 'Cardiac diseases',
                        'B': 'Diseases of the nervous system, cerebrovascular accident (stroke)',
                        'C': 'Geriatric Medicine',
                        'D': 'Lung diseases',
                        'E': 'Diseases of the abdominal organs',
                        'F': 'Vascular Diseases',
                        'G': 'Gynecology and obstetrics',
                        'H': 'Diseases of the urinary tract and male genitalia',
                        'I': 'Diseases of the bones, joints, connective tissues',
                        'J': 'Complex conditions',
                        'K': 'Skin disorders',
                        'L': 'Highly specialized medicine',
                        'M': 'Palliative Medicine',
                        }
  df['disease_group'] = df['main_code'].map(disease_group_dict)
  df = df.astype({'number_of_cases_2014-2018' : 'int'})
  df = df.astype({'number_of_cases_2019' : 'int'})
  sum_column = df["number_of_cases_2014-2018"] + df["number_of_cases_2019"]
  df['number_of_cases_2014_2019'] = sum_column

  hospit_city_canton = pd.read_csv(
      'src/processed/hospitals_with_city_canton.csv', sep=';'
      )
  hospit_city_canton = hospit_city_canton.merge(df, on="hospital")
  hospit_city_canton.drop(['Unnamed: 0_x', 
                           'canton_english', 
                           'Unnamed: 0_y', 
                           'indicator', 
                           'therapeutic_value_2014-2018', 
                           'therapeutic_value_2019', 
                           'None'], 
                            axis=1, inplace=True)
  hospit_city_canton = hospit_city_canton[[
                                           'hospital', 'city', 'canton_name', 
                                           'main_code', 'disease_group', 'code', 
                                           'age_cat', 'mortality', 'indicator_eng', 
                                           'number_of_cases_2014_2019', 
                                           'number_of_cases_2014-2018', 
                                           'number_of_cases_2019',
                                            'observed_rate_2014-2018_%',	
                                           'expected_rate_2014-2018_%',	
                                           'observed_rate_2019_%',	
                                            'expected_rate_2019_%']]
  hospit_city_canton_disease_group = hospit_city_canton.astype(
        {'number_of_cases_2019' : 'int'}).groupby([
                                                   'hospital', 'city', 
                                                   'canton_name', 'main_code', 
                                                   'disease_group'])['number_of_cases_2014_2019'].agg(['sum'])
  hospit_city_canton_disease_group.to_csv(
      'src/processed/hospital_canton_group.csv'
      )
  quality_indic_disease_sum = pd.read_csv(
      'src/processed/processed_data/hospital_canton_group.csv'
      )
  quality_indic_disease_sum.rename(columns={"sum": "number_of_cases_2014_2019"}, inplace=True)
  quality_indic_disease_sum = quality_indic_disease_sum[
                                                        quality_indic_disease_sum['number_of_cases_2014_2019'] != 0]
  quality_indic_disease_sum.reset_index(inplace=True)
  quality_indic_disease_sum.drop(['index'], axis=1, inplace=True)
  return quality_indic_disease_sum

# %%
read_qual2_2019 = pd.read_csv('src/processed/processed_quality_indicators.csv')

# %%
hospital_cantons = merge_hospital_cantons(read_qual2_2019)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
hospital_cantons
# Out:
#                     hospital       city canton_name main_code  \
# 0             Adus Medica AG  Dielsdorf      Zürich         E
# 1             Adus Medica AG  Dielsdorf      Zürich         F
# 2             Adus Medica AG  Dielsdorf      Zürich         G
# 3             Adus Medica AG  Dielsdorf      Zürich         H
# 4             Adus Medica AG  Dielsdorf      Zürich         I
# ...                      ...        ...         ...       ...
# 1497  Zuger Kantonsspital AG       Baar         Zug         H
# 1498  Zuger Kantonsspital AG       Baar         Zug         I
# 1499  Zuger Kantonsspital AG       Baar         Zug         J
# 1500  Zuger Kantonsspital AG       Baar         Zug         K
# 1501  Zuger Kantonsspital AG       Baar         Zug         M
#
#                                           disease_group  \
# 0                      Diseases of the abdominal organs
# 1                                     Vascular Diseases
# 2                             Gynecology and obstetrics
# 3      Diseases of the urinary tract and male genitalia
# 4     Diseases of the bones, joints, connective tissues
# ...                                                 ...
# 1497   Diseases of the urinary tract and male genitalia
# 1498  Diseases of the bones, joints, connective tissues
# 1499                                 Complex conditions
# 1500                                     Skin disorders
# 1501                                Palliative Medicine
#
#       number_of_cases_2014_2019
# 0                          1266
# 1                             2
# 2                            31
# 3                             4
# 4                           131
# ...                         ...
# 1497                       4557
# 1498                       3529
# 1499                       3350
# 1500                         67
# 1501                          1
#
# [1502 rows x 6 columns]

# %%
canton_check = hospital_cantons.canton_name.drop_duplicates()

# %%
canton_check.reset_index()
# Out:
#     index             canton_name
# 0       0                  Zürich
# 1       6                     Zug
# 2      17                  Aargau
# 3      39  Appenzell Ausserrhoden
# 4      48             Basel-stadt
# 5      59                    Vaud
# 6      72                  Ticino
# 7      82              Graubünden
# 8     164                  Valais
# 9     173                  Genève
# 10    184               Neuchâtel
# 11    327                    Bern
# 12    328              St. Gallen
# 13    329               Nidwalden
# 14    330        Basel-Landschaft
# 15    331                  Luzern
# 16    361                Fribourg
# 17    373                 Thurgau
# 18    414            Schaffhausen
# 19    557                    Jura
# 20    619   Appenzell Innerrhoden
# 21    667                  Glarus
# 22    702                Obwalden
# 23    726                     Uri
# 24   1058               Solothurn
# 25   1107                  Schwyz

# %% [markdown]
# # Plotting according to:

# %% [markdown]
# ## Disease number per disease group in cantons

# %% [markdown]
# 1. Without G

# %%
hospital_cantons
# Out:
#                     hospital       city canton_name main_code  \
# 0             Adus Medica AG  Dielsdorf      Zürich         E
# 1             Adus Medica AG  Dielsdorf      Zürich         F
# 2             Adus Medica AG  Dielsdorf      Zürich         G
# 3             Adus Medica AG  Dielsdorf      Zürich         H
# 4             Adus Medica AG  Dielsdorf      Zürich         I
# ...                      ...        ...         ...       ...
# 1497  Zuger Kantonsspital AG       Baar         Zug         H
# 1498  Zuger Kantonsspital AG       Baar         Zug         I
# 1499  Zuger Kantonsspital AG       Baar         Zug         J
# 1500  Zuger Kantonsspital AG       Baar         Zug         K
# 1501  Zuger Kantonsspital AG       Baar         Zug         M
#
#                                           disease_group  \
# 0                      Diseases of the abdominal organs
# 1                                     Vascular Diseases
# 2                             Gynecology and obstetrics
# 3      Diseases of the urinary tract and male genitalia
# 4     Diseases of the bones, joints, connective tissues
# ...                                                 ...
# 1497   Diseases of the urinary tract and male genitalia
# 1498  Diseases of the bones, joints, connective tissues
# 1499                                 Complex conditions
# 1500                                     Skin disorders
# 1501                                Palliative Medicine
#
#       number_of_cases_2014_2019
# 0                          1266
# 1                             2
# 2                            31
# 3                             4
# 4                           131
# ...                         ...
# 1497                       4557
# 1498                       3529
# 1499                       3350
# 1500                         67
# 1501                          1
#
# [1502 rows x 6 columns]

# %%
group_disease_cantons_wo_G = hospital_cantons[~hospital_cantons['main_code'].str.contains('G')]

# %%
group_disease_cantons_wo_G = group_disease_cantons_wo_G.astype(
        {'number_of_cases_2014_2019' : 'int'}).groupby(['canton_name', 'main_code', 'disease_group']).agg({'number_of_cases_2014_2019':'max'})

# %%
group_disease_cantons_wo_G.reset_index(inplace=True)

# %%
group_disease_cantons_wo_G = group_disease_cantons_wo_G.sort_values('number_of_cases_2014_2019', ascending=False).drop_duplicates(['canton_name'])
group_disease_cantons_wo_G
# Out:
#                 canton_name main_code  \
# 56                     Bern         A
# 280                  Zürich         A
# 44              Basel-stadt         A
# 257                    Vaud         A
# 200              St. Gallen         A
# 223                  Ticino         A
# 79                   Genève         A
# 124                  Luzern         A
# 0                    Aargau         A
# 245                  Valais         A
# 68                 Fribourg         A
# 188               Solothurn         A
# 212                 Thurgau         A
# 32         Basel-Landschaft         A
# 102              Graubünden         A
# 143               Neuchâtel         I
# 276                     Zug         I
# 113                    Jura         A
# 167            Schaffhausen         A
# 19   Appenzell Ausserrhoden         I
# 181                  Schwyz         E
# 147               Nidwalden         A
# 91                   Glarus         A
# 242                     Uri         I
# 157                Obwalden         A
# 29    Appenzell Innerrhoden         I
#
#                                          disease_group  \
# 56                                    Cardiac diseases
# 280                                   Cardiac diseases
# 44                                    Cardiac diseases
# 257                                   Cardiac diseases
# 200                                   Cardiac diseases
# 223                                   Cardiac diseases
# 79                                    Cardiac diseases
# 124                                   Cardiac diseases
# 0                                     Cardiac diseases
# 245                                   Cardiac diseases
# 68                                    Cardiac diseases
# 188                                   Cardiac diseases
# 212                                   Cardiac diseases
# 32                                    Cardiac diseases
# 102                                   Cardiac diseases
# 143  Diseases of the bones, joints, connective tissues
# 276  Diseases of the bones, joints, connective tissues
# 113                                   Cardiac diseases
# 167                                   Cardiac diseases
# 19   Diseases of the bones, joints, connective tissues
# 181                   Diseases of the abdominal organs
# 147                                   Cardiac diseases
# 91                                    Cardiac diseases
# 242  Diseases of the bones, joints, connective tissues
# 157                                   Cardiac diseases
# 29   Diseases of the bones, joints, connective tissues
#
#      number_of_cases_2014_2019
# 56                      168902
# 280                     119576
# 44                      111792
# 257                      82536
# 200                      79363
# 223                      78430
# 79                       77693
# 124                      72441
# 0                        60110
# 245                      47148
# 68                       42398
# 188                      40180
# 212                      37906
# 32                       35153
# 102                      34675
# 143                      30798
# 276                       8635
# 113                       8305
# 167                       7330
# 19                        6047
# 181                       5774
# 147                       5298
# 91                        4075
# 242                       3981
# 157                       3439
# 29                         739

# %%
fig = px.histogram(group_disease_cantons_wo_G, x="canton_name", y="number_of_cases_2014_2019", color="disease_group", log_x=False, width=1500, height=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1fef7af8-39a1-4d11-9dff-2c5eef97bbb8" class="plotly-graph-div" style="height:1000px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fef7af8-39a1-4d11-9dff-2c5eef97bbb8")) {                    Plotly.newPlot(                        "1fef7af8-39a1-4d11-9dff-2c5eef97bbb8",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"disease_group=Cardiac diseases<br>canton_name=%{x}<br>sum of number_of_cases_2014_2019=%{y}<extra></extra>","legendgroup":"Cardiac diseases","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cardiac diseases","offsetgroup":"Cardiac diseases","orientation":"v","showlegend":true,"x":["Bern","Z\u00fcrich","Basel-stadt","Vaud","St. Gallen","Ticino","Gen\u00e8ve","Luzern","Aargau","Valais","Fribourg","Solothurn","Thurgau","Basel-Landschaft","Graub\u00fcnden","Jura","Schaffhausen","Nidwalden","Glarus","Obwalden"],"xaxis":"x","y":[168902,119576,111792,82536,79363,78430,77693,72441,60110,47148,42398,40180,37906,35153,34675,8305,7330,5298,4075,3439],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"disease_group=Diseases of the bones, joints, connective tissues<br>canton_name=%{x}<br>sum of number_of_cases_2014_2019=%{y}<extra></extra>","legendgroup":"Diseases of the bones, joints, connective tissues","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Diseases of the bones, joints, connective tissues","offsetgroup":"Diseases of the bones, joints, connective tissues","orientation":"v","showlegend":true,"x":["Neuch\u00e2tel","Zug","Appenzell Ausserrhoden","Uri","Appenzell\u00a0Innerrhoden"],"xaxis":"x","y":[30798,8635,6047,3981,739],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"disease_group=Diseases of the abdominal organs<br>canton_name=%{x}<br>sum of number_of_cases_2014_2019=%{y}<extra></extra>","legendgroup":"Diseases of the abdominal organs","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Diseases of the abdominal organs","offsetgroup":"Diseases of the abdominal organs","orientation":"v","showlegend":true,"x":["Schwyz"],"xaxis":"x","y":[5774],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f ...

# %% [markdown]
# 2. With G

# %%
group_diseases_cantons_g = hospital_cantons.astype(
        {'number_of_cases_2014_2019' : 'int'}).groupby(['canton_name', 'main_code', 'disease_group']).agg({'number_of_cases_2014_2019':'max'})

# %%
group_diseases_cantons_g
# Out:
#                                                                           number_of_cases_2014_2019
# canton_name main_code disease_group
# Aargau      A         Cardiac diseases                                                        60110
#             B         Diseases of the nervous system, cerebrovascular...                      30056
#             C         Geriatric Medicine                                                       6631
#             D         Lung diseases                                                           13542
#             E         Diseases of the abdominal organs                                        15259
# ...                                                                                             ...
# Zürich      I         Diseases of the bones, joints, connective tissues                       28179
#             J         Complex conditions                                                      37809
#             K         Skin disorders                                                           3367
#             L         Highly specialized medicine                                              4184
#             M         Palliative Medicine                                                      2486
#
# [318 rows x 1 columns]

# %%
group_diseases_cantons_g.reset_index(inplace=True)

# %%
most_pop_disease_canton = group_diseases_cantons_g.sort_values('number_of_cases_2014_2019', ascending=False).drop_duplicates(['canton_name'])
most_pop_disease_canton
# Out:
#                 canton_name main_code  \
# 61                     Bern         A
# 305                  Zürich         A
# 48              Basel-stadt         A
# 92                   Genève         G
# 280                    Vaud         A
# 141                  Luzern         G
# 218              St. Gallen         A
# 243                  Ticino         A
# 0                    Aargau         A
# 237                 Thurgau         G
# 267                  Valais         A
# 74                 Fribourg         A
# 205               Solothurn         A
# 35         Basel-Landschaft         A
# 154               Neuchâtel         G
# 111              Graubünden         A
# 19   Appenzell Ausserrhoden         G
# 188            Schaffhausen         G
# 299                     Zug         G
# 129                    Jura         G
# 166               Nidwalden         G
# 199                  Schwyz         G
# 105                  Glarus         G
# 262                     Uri         G
# 177                Obwalden         G
# 32    Appenzell Innerrhoden         I
#
#                                          disease_group  \
# 61                                    Cardiac diseases
# 305                                   Cardiac diseases
# 48                                    Cardiac diseases
# 92                           Gynecology and obstetrics
# 280                                   Cardiac diseases
# 141                          Gynecology and obstetrics
# 218                                   Cardiac diseases
# 243                                   Cardiac diseases
# 0                                     Cardiac diseases
# 237                          Gynecology and obstetrics
# 267                                   Cardiac diseases
# 74                                    Cardiac diseases
# 205                                   Cardiac diseases
# 35                                    Cardiac diseases
# 154                          Gynecology and obstetrics
# 111                                   Cardiac diseases
# 19                           Gynecology and obstetrics
# 188                          Gynecology and obstetrics
# 299                          Gynecology and obstetrics
# 129                          Gynecology and obstetrics
# 166                          Gynecology and obstetrics
# 199                          Gynecology and obstetrics
# 105                          Gynecology and obstetrics
# 262                          Gynecology and obstetrics
# 177                          Gynecology and obstetrics
# 32   Diseases of the bones, joints, connective tissues
#
#      number_of_cases_2014_2019
# 61                      168902
# 305                     119576
# 48                      111792
# 92                       87714
# 280                      82536
# 141                      79503
# 218                      79363
# 243                      78430
# 0                        60110
# 237                      56286
# 267                      47148
# 74                       42398
# 205                      40180
# 35                       35153
# 154                      34713
# 111                      34675
# 19                       23756
# 188                      21464
# 299                      21211
# 129                      12684
# 166                      11428
# 199                       9881
# 105                       8961
# 262                       6495
# 177                       5654
# 32                         739

# %%
fig = px.histogram(most_pop_disease_canton, x="canton_name", y="number_of_cases_2014_2019", color="disease_group", log_x=False, width=1500, height=1000)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="47e25214-ef9b-49a2-a4d6-e18cfa499933" class="plotly-graph-div" style="height:1000px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47e25214-ef9b-49a2-a4d6-e18cfa499933")) {                    Plotly.newPlot(                        "47e25214-ef9b-49a2-a4d6-e18cfa499933",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"disease_group=Cardiac diseases<br>canton_name=%{x}<br>sum of number_of_cases_2014_2019=%{y}<extra></extra>","legendgroup":"Cardiac diseases","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cardiac diseases","offsetgroup":"Cardiac diseases","orientation":"v","showlegend":true,"x":["Bern","Z\u00fcrich","Basel-stadt","Vaud","St. Gallen","Ticino","Aargau","Valais","Fribourg","Solothurn","Basel-Landschaft","Graub\u00fcnden"],"xaxis":"x","y":[168902,119576,111792,82536,79363,78430,60110,47148,42398,40180,35153,34675],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"disease_group=Gynecology and obstetrics<br>canton_name=%{x}<br>sum of number_of_cases_2014_2019=%{y}<extra></extra>","legendgroup":"Gynecology and obstetrics","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Gynecology and obstetrics","offsetgroup":"Gynecology and obstetrics","orientation":"v","showlegend":true,"x":["Gen\u00e8ve","Luzern","Thurgau","Neuch\u00e2tel","Appenzell Ausserrhoden","Schaffhausen","Zug","Jura","Nidwalden","Schwyz","Glarus","Uri","Obwalden"],"xaxis":"x","y":[87714,79503,56286,34713,23756,21464,21211,12684,11428,9881,8961,6495,5654],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"disease_group=Diseases of the bones, joints, connective tissues<br>canton_name=%{x}<br>sum of number_of_cases_2014_2019=%{y}<extra></extra>","legendgroup":"Diseases of the bones, joints, connective tissues","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Diseases of the bones, joints, connective tissues","offsetgroup":"Diseases of the bones, joints, connective tissues","orientation":"v","showlegend":true,"x":["Appenzell\u00a0Innerrhoden"],"xaxis":"x","y":[739],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap" ...

# %% [markdown]
# ## 3. Choropleth map containing cantons with hospitals and numbers of diseases:

# %%
lon_lat_quality_df = pd.read_csv('src/processed/lon_lat_quality_df.csv')

# %%
lon_lat_quality_df
# Out:
#      Unnamed: 0      lat     lng  population  population_proper          city  \
# 0             0  47.3786  8.5400    434008.0           434008.0        Zürich
# 1             1  47.3786  8.5400    434008.0           434008.0        Zürich
# 2             2  47.3786  8.5400    434008.0           434008.0        Zürich
# 3             3  47.3786  8.5400    434008.0           434008.0        Zürich
# 4             4  47.3786  8.5400    434008.0           434008.0        Zürich
# ..          ...      ...     ...         ...                ...           ...
# 129         129  46.5336  9.8719      2924.0             2924.0       Samedan
# 130         130  47.4012  8.2153      2897.0             2897.0  Othmarsingen
# 131         131  46.9664  9.6833      2679.0             2679.0       Schiers
# 132         132  47.5819  8.2194      2169.0             2169.0      Leuggern
# 133         133  46.4333  6.2167      1937.0             1937.0      Genolier
#
#     canton_name                       hospital  number_of_cases
# 0        Zürich            Geburtshaus Delphys             2418
# 1        Zürich           Klinik Hirslanden AG           189222
# 2        Zürich                 Klinik Im Park            70258
# 3        Zürich      Klinik Pyramide am See AG             8488
# 4        Zürich                Limmatklinik AG             5004
# ..          ...                            ...              ...
# 129  Graubünden             Spital Oberengadin            11491
# 130      Aargau    Geburtshus Storchenäscht AG             1944
# 131  Graubünden  Flury Stiftung Spital Schiers            11939
# 132      Aargau       Asana Spital Leuggern AG            22792
# 133        Vaud           Clinique de Genolier            15677
#
# [134 rows x 9 columns]

# %%
with open("src/raw/georef-switzerland-kanton.geojson") as response:
    cantons = json.load(response)

cantons["features"][0]["properties"]
# Out:
# {'geo_point_2d': [46.2204844659, 6.13300925662],
#  'kan_area_code': 'CHE',
#  'kan_code': '25',
#  'kan_name': 'Genève',
#  'kan_type': 'Kanton',
#  'year': '2020'}

# %%
 fig = px.scatter_mapbox(
    lon_lat_quality_df, 
    color="number_of_cases",
    size='number_of_cases',
    lat='lat', lon='lng', 
    center={"lat": 46.8, "lon": 8.3},
    hover_data=['hospital', 'number_of_cases', 'city', 'canton_name'],
    mapbox_style="open-street-map", 
    zoom=6.3,
    opacity=0.8,
    width=900,
    height=500,
    labels={"canton_name":"Canton",
            "hospital": "Hospital",
            "city": "City",
            "number_of_cases":"Number of cases"},
    title="<b>Number of cases 2014-2019 per hospital</b>",
    color_continuous_scale="Viridis"
)
fig.update_layout(margin={"r":0,"t":35,"l":0,"b":0},
                  font={"family":"Sans",
                       "color":"maroon"},
                  hoverlabel={"bgcolor":"white", 
                              "font_size":15,
                             "font_family":"Arial"},
                  title={"font_size":20,
                        "xanchor":"left", "x":0.01,
                        "yanchor":"bottom", "y":0.95}
                 )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1bd158b7-e177-4ee3-82d9-2161aac3f066" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bd158b7-e177-4ee3-82d9-2161aac3f066")) {                    Plotly.newPlot(                        "1bd158b7-e177-4ee3-82d9-2161aac3f066",                        [{"customdata":[["Geburtshaus Delphys",2418,"Z\u00fcrich","Z\u00fcrich"],["Klinik Hirslanden AG",189222,"Z\u00fcrich","Z\u00fcrich"],["Klinik Im Park",70258,"Z\u00fcrich","Z\u00fcrich"],["Klinik Pyramide am See AG",8488,"Z\u00fcrich","Z\u00fcrich"],["Limmatklinik AG",5004,"Z\u00fcrich","Z\u00fcrich"],["Privatklinik Bethanien",25271,"Z\u00fcrich","Z\u00fcrich"],["Schulthess Klinik",28797,"Z\u00fcrich","Z\u00fcrich"],["Stadtspital Triemli",234004,"Z\u00fcrich","Z\u00fcrich"],["Stadtspital Waid",57640,"Z\u00fcrich","Z\u00fcrich"],["Universit\u00e4ts-Kinderspital Z\u00fcrich das Spital der Eleonorenstiftung",24800,"Z\u00fcrich","Z\u00fcrich"],["Universit\u00e4tsklinik Balgrist",17918,"Z\u00fcrich","Z\u00fcrich"],["Universit\u00e4tsspital Z\u00fcrich",356599,"Z\u00fcrich","Z\u00fcrich"],["Clinique G\u00e9n\u00e9rale\u00adBeaulieu",36184,"Geneva","Gen\u00e8ve"],["Clinique de la Plaine",263,"Geneva","Gen\u00e8ve"],["Clinique la Colline",13048,"Geneva","Gen\u00e8ve"],["Les H\u00f4pitaux Universitaires de Gen\u00e8ve HUG",360584,"Geneva","Gen\u00e8ve"],["Maison de naissance La Roseraie",1046,"Geneva","Gen\u00e8ve"],["Bethesda Spital AG",60119,"Basel","Basel-stadt"],["Geburtshaus Basel",42,"Basel","Basel-stadt"],["Matthea Geburtshaus",179,"Basel","Basel-stadt"],["Merian Iselin Klinik",19496,"Basel","Basel-stadt"],["St. Claraspital",78985,"Basel","Basel-stadt"],["Universit\u00e4tsspital Basel",318065,"Basel","Basel-stadt"],["Universit\u00e4ts\u00adKinderspital beider Basel (UKBB)",11149,"Basel","Basel-stadt"],["CHUV Centre Hospitalier Universitaire Vaudois",313080,"Lausanne","Vaud"],["Clinique de La Source",40804,"Lausanne","Vaud"],["Clinique de Montchoisi",2081,"Lausanne","Vaud"],["Hirslanden Lausanne SA",66691,"Lausanne","Vaud"],["Hirslanden Bern AG",158824,"Bern","Bern"],["Insel Gruppe AG (nicht-universit\u00e4r)",121280,"Bern","Bern"],["Insel Gruppe AG (universit\u00e4r)",419355,"Bern","Bern"],["Lindenhofgruppe AG",206008,"Bern","Bern"],["Stiftung Diaconis Palliative Care",1696,"Bern","Bern"],["Eulachklinik AG",10,"Winterthur","Z\u00fcrich"],["Kantonsspital Winterthur",185643,"Winterthur","Z\u00fcrich"],["Privatklinik Lindberg",7742,"Winterthur","Z\u00fcrich"],["Geburtshaus St.Gallen GmbH",323,"Sankt Gallen","St. Gallen"],["Hirslanden Klinik Stephanshorn",57857,"Sankt Gallen","St. Gallen"],["Kantonsspital St. Gallen",272554,"Sankt Gallen","St. Gallen"],["Stiftung Ostschweizer Kinderspital",7441,"Sankt Gallen","St. Gallen"],["Cardiocentro Ticino (CCT)",83120,"Lugano","Ticino"],["Clinica Luganese Moncucco SA",43793,"Lugano","Ticino"],["EOC Ente ospedaliero cantonale",232748,"Lugano","Ticino"],["Hirslanden Klinik Linde AG",40271,"Biel/Bienne","Bern"],["Spitalzentrum Biel AG",87052,"Biel/Bienne","Bern"],["Klinik Hohmad AG",5102,"Thun","Bern"],["Spital STS AG",99727,"Thun","Bern"],["Clinique Volta SA",112,"La Chaux-de-Fonds","Neuch\u00e2tel"],["R\u00e9seau hospitalier neuch\u00e2telois RHNe",118077,"La Chaux-de-Fonds","Neuch\u00e2tel"],["SMN",80773,"La Chaux-de-Fonds","Neuch\u00e2tel"],["HFR",142840,"Fribourg","Fribourg"],["H\u00f4pital Jules Daler",56008,"Fribourg","Fribourg"],["Hirslanden Klinik Belair",6352,"Schaffhausen","Schaffhausen"],["Spit\u00e4ler Schaffhausen",59740,"Schaffhausen","Schaffhausen"],["Kantonsspital Graub\u00fcnden",129449,"Chur","Graub\u00fcnden"],["H\u00f4pital du Valais Centre hospitalier du Valais Romand CHVR",179899,"Sion","Valais"],["Spital Uster",61668,"Uster","Z\u00fcrich ...
